# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek09thakur/Roadmap/blob/main/Coding/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hello, World!**
# > After the recession and the onboarding now I am back!

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## **Let's Start**

# %%
print('Hello, World')
# Out:
# Hello, World
