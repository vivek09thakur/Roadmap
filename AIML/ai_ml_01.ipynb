# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek09thakur/Roadmap/blob/main/AIML/ai_ml_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PYTHON FOR DATA SCIENCE**

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# - **DATA TYPES AND VARIABLES**
#     - Primitive Data Types:
#         - Int
#         - Float
#         - String
#         - Boolean
#     - Non-Primitive Data Types (User Defined Types):
#         - List
#         - Dictionary
#         - Tuple
#         - Array

# %%
var_a = 5
var_a
# Out:
# 5

# %%
type(var_a)
# Out:
# int

# %%
var_b = 7.5367322328337883443876884339638923
var_b
# Out:
# 7.5367322328337885

# %%
type(var_b)
# Out:
# float

# %%
var_c = "Hello World!"
var_c
# Out:
# 'Hello World!'

# %%
type(var_c)
# Out:
# str

# %%
var_d = True
var_e = False
var_d, var_e
# Out:
# (True, False)

# %%
type(var_d), type(var_e)
# Out:
# (bool, bool)
