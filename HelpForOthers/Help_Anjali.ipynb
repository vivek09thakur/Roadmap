# %% [markdown]
# ## Help for Anjali

# %%
i = 2
for x in range(i):
    x += 1
    print(x)
    print("X")
# Out:
# 1
# X
# 2
# X

# %%
i = 2
for x in range(i):
    x += 1
    print(x)
print(x)
# Out:
# 1
# 2
# 2
