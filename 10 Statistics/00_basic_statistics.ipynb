# %% [markdown]
# ## **STATISTICS**

# %% [markdown]
# **Basic Definitions**
#
# *Statistics* is a branch of mathematics that deals with the collection, analysis, interpretation, and presentation of masses of numerical data. Statistics is used in almost every field of research and is considered a mathematical science.

# %% [markdown]
# ### **LET'S DIVE INTO THE CODE**
#
# > Here we are going to implement statistics that we have learned. So, without wasting any time on already known theory and calculational part, let's dive into the code.
